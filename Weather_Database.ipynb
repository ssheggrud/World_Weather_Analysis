# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from scipy import stats

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Import the datetime module from the datetime library.
from datetime import datetime

# %%
# Create a set of 2,000 random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 768

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1

# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_d
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | yellowknife
# Processing Record 2 of Set 1 | palabuhanratu
# City not found. Skipping...
# Processing Record 3 of Set 1 | komsomolskiy
# Processing Record 4 of Set 1 | chulym
# Processing Record 5 of Set 1 | khatanga
# Processing Record 6 of Set 1 | albany
# Processing Record 7 of Set 1 | avarua
# Processing Record 8 of Set 1 | sobolevo
# Processing Record 9 of Set 1 | awjilah
# Processing Record 10 of Set 1 | coquimbo
# Processing Record 11 of Set 1 | thompson
# Processing Record 12 of Set 1 | hudesti
# Processing Record 13 of Set 1 | amapa
# Processing Record 14 of Set 1 | kurilsk
# Processing Record 15 of Set 1 | kirakira
# Processing Record 16 of Set 1 | busselton
# Processing Record 17 of Set 1 | shenjiamen
# Processing Record 18 of Set 1 | safwah
# City not found. Skipping...
# Processing Record 19 of Set 1 | jamestown
# Processing Record 20 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 21 of Set 1 | igarka
# Processing Record 22 of Set 1 | atuona
# Processing Record 23 of Set 1 | faanui
# Processing Record 24 of Set 1 | mataura
# Processing Record 25 of Set 1 | ushuaia
# Processing Record 26 of Set 1 | vaini
# Processing Record 27 of Set 1 | new norfolk
# Processing Record 28 of Set 1 | bredasdorp
# Processing Record 29 of Set 1 | tasiilaq
# Processing Record 30 of Set 1 | port alfred
# Processing Record 31 of Set 1 | tawkar
# City not found. Skipping...
# Processing Record 32 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 33 of Set 1 | hilo
# Processing Record 34 of Set 1 | port hedland
# Processing Record 35 of Set 1 | punta arenas
# Processing Record 36 of Set 1 | clyde river
# Processing Record 37 of Set 1 | bilibino
# Processing Record 38 of Set 1 | san policarpo
# Processing Record 39 of Set 1 | hirara
# Processing Record 40 of Set 1 | kaitangata
# Processing Record 41 of Set 1 | port elizabeth
# Processing Record 42 of Set 1 | samarai
# Processing Record 43 of Set 1 | grand river south east
# City not found. Skipping...
# Processing Record 44 of Set 1 | shahreza
# Processing Record 45 of Set 1 | sentyabrskiy
# City not found. Skipping...
# Processing Record 46 of Set 1 | dikson
# Processing Record 47 of Set 1 | saint-philippe
# Processing Record 48 of Set 1 | codrington
# Processing Record 49 of Set 1 | lompoc
# Processing Record 50 of Set 1 | paamiut
# Processing Record 1 of Set 2 | bolungarvik
# City not found. Skipping...
# Processing Record 2 of Set 2 | galiwinku
# City not found. Skipping...
# Processing Record 3 of Set 2 | port hardy
# Processing Record 4 of Set 2 | severo-kurilsk
# Processing Record 5 of Set 2 | karratha
# Processing Record 6 of Set 2 | goure
# Processing Record 7 of Set 2 | santa maria
# Processing Record 8 of Set 2 | san quintin
# Processing Record 9 of Set 2 | rikitea
# Processing Record 10 of Set 2 | huron
# Processing Record 11 of Set 2 | vilhena
# Processing Record 12 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 13 of Set 2 | cape town
# Processing Record 14 of Set 2 | spearfish
# Processing Record 15 of Set 2 | souillac
# Processing Record 16 of Set 2 | la campana
# Processing Record 17 of Set 2 | bulgan
# Processing Record 18 of Set 2 | naze
# Processing Record 19 of Set 2 | san carlos de bariloche
# Processing Record 20 of Set 2 | lavrentiya
# Processing Record 21 of Set 2 | yenagoa
# Processing Record 22 of Set 2 | wielun
# Processing Record 23 of Set 2 | georgetown
# Processing Record 24 of Set 2 | conceicao do araguaia
# Processing Record 25 of Set 2 | hermanus
# Processing Record 26 of Set 2 | fallon
# Processing Record 27 of Set 2 | luderitz
# Processing Record 28 of Set 2 | abnub
# Processing Record 29 of Set 2 | namibe
# Processing Record 30 of Set 2 | marsh harbour
# Processing Record 31 of Set 2 | barrow
# Processing Record 32 of Set 2 | praya
# Processing Record 33 of Set 2 | korsakov
# Processing Record 34 of Set 2 | klaksvik
# Processing Record 35 of Set 2 | matara
# Processing Record 36 of Set 2 | butaritari
# Processing Record 37 of Set 2 | kolda
# Processing Record 38 of Set 2 | bethel
# Processing Record 39 of Set 2 | arraial do cabo
# Processing Record 40 of Set 2 | pimentel
# Processing Record 41 of Set 2 | sabile
# Processing Record 42 of Set 2 | sabancuy
# Processing Record 43 of Set 2 | niles
# Processing Record 44 of Set 2 | emerald
# Processing Record 45 of Set 2 | road town
# Processing Record 46 of Set 2 | gejiu
# Processing Record 47 of Set 2 | wrexham
# Processing Record 48 of Set 2 | saint george
# Processing Record 49 of Set 2 | mar del plata
# Processing Record 50 of Set 2 | ust-kuyga
# Processing Record 1 of Set 3 | cap malheureux
# Processing Record 2 of Set 3 | nanortalik
# Processing Record 3 of Set 3 | dryden
# Processing Record 4 of Set 3 | los llanos de aridane
# Processing Record 5 of Set 3 | kodiak
# Processing Record 6 of Set 3 | sulangan
# Processing Record 7 of Set 3 | bull savanna
# Processing Record 8 of Set 3 | saskylakh
# Processing Record 9 of Set 3 | ullapool
# Processing Record 10 of Set 3 | fortuna
# Processing Record 11 of Set 3 | castro
# Processing Record 12 of Set 3 | chokurdakh
# Processing Record 13 of Set 3 | cap-aux-meules
# Processing Record 14 of Set 3 | solovetskiy
# City not found. Skipping...
# Processing Record 15 of Set 3 | aleppo
# Processing Record 16 of Set 3 | puerto escondido
# Processing Record 17 of Set 3 | merauke
# Processing Record 18 of Set 3 | sinnamary
# Processing Record 19 of Set 3 | hithadhoo
# Processing Record 20 of Set 3 | ordu
# Processing Record 21 of Set 3 | maniitsoq
# Processing Record 22 of Set 3 | krasnyy chikoy
# Processing Record 23 of Set 3 | moerai
# Processing Record 24 of Set 3 | ouadda
# Processing Record 25 of Set 3 | jodhpur
# Processing Record 26 of Set 3 | veraval
# Processing Record 27 of Set 3 | tuktoyaktuk
# Processing Record 28 of Set 3 | egvekinot
# Processing Record 29 of Set 3 | bluff
# Processing Record 30 of Set 3 | sechura
# Processing Record 31 of Set 3 | marawi
# Processing Record 32 of Set 3 | svetlyy
# Processing Record 33 of Set 3 | geraldton
# Processing Record 34 of Set 3 | ponta do sol
# Processing Record 35 of Set 3 | ahipara
# Processing Record 36 of Set 3 | fort nelson
# Processing Record 37 of Set 3 | qaanaaq
# Processing Record 38 of Set 3 | lebu
# Processing Record 39 of Set 3 | san patricio
# Processing Record 40 of Set 3 | flinders
# Processing Record 41 of Set 3 | northview
# Processing Record 42 of Set 3 | nome
# Processing Record 43 of Set 3 | espinosa
# Processing Record 44 of Set 3 | guerrero negro
# Processing Record 45 of Set 3 | neuquen
# Processing Record 46 of Set 3 | alta floresta
# Processing Record 47 of Set 3 | hobart
# Processing Record 48 of Set 3 | esperance
# Processing Record 49 of Set 3 | kazachinskoye
# Processing Record 50 of Set 3 | beyneu
# Processing Record 1 of Set 4 | ossora
# Processing Record 2 of Set 4 | east london
# Processing Record 3 of Set 4 | longyearbyen
# Processing Record 4 of Set 4 | port lincoln
# Processing Record 5 of Set 4 | carutapera
# Processing Record 6 of Set 4 | linxia
# Processing Record 7 of Set 4 | belushya guba
# City not found. Skipping...
# Processing Record 8 of Set 4 | beringovskiy
# Processing Record 9 of Set 4 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 10 of Set 4 | necochea
# Processing Record 11 of Set 4 | nueva fuerza
# Processing Record 12 of Set 4 | puerto ayora
# Processing Record 13 of Set 4 | toyooka
# Processing Record 14 of Set 4 | los altos
# Processing Record 15 of Set 4 | saint-augustin
# Processing Record 16 of Set 4 | victoria
# Processing Record 17 of Set 4 | flin flon
# Processing Record 18 of Set 4 | coracao de jesus
# Processing Record 19 of Set 4 | inverell
# Processing Record 20 of Set 4 | hoquiam
# Processing Record 21 of Set 4 | galesburg
# Processing Record 22 of Set 4 | upernavik
# Processing Record 23 of Set 4 | kudahuvadhoo
# Processing Record 24 of Set 4 | samalaeulu
# City not found. Skipping...
# Processing Record 25 of Set 4 | kendari
# Processing Record 26 of Set 4 | seddon
# Processing Record 27 of Set 4 | grand gaube
# Processing Record 28 of Set 4 | provideniya
# Processing Record 29 of Set 4 | qaqortoq
# Processing Record 30 of Set 4 | debre zeyit
# Processing Record 31 of Set 4 | skalistyy
# City not found. Skipping...
# Processing Record 32 of Set 4 | tual
# Processing Record 33 of Set 4 | kruisfontein
# Processing Record 34 of Set 4 | ilulissat
# Processing Record 35 of Set 4 | swift current
# Processing Record 36 of Set 4 | ancud
# Processing Record 37 of Set 4 | chipinge
# Processing Record 38 of Set 4 | aklavik
# Processing Record 39 of Set 4 | baruun-urt
# Processing Record 40 of Set 4 | buin
# Processing Record 41 of Set 4 | kapaa
# Processing Record 42 of Set 4 | san carlos
# Processing Record 43 of Set 4 | bubaque
# Processing Record 44 of Set 4 | wajir
# Processing Record 45 of Set 4 | kavaratti
# Processing Record 46 of Set 4 | touros
# Processing Record 47 of Set 4 | saleaula
# City not found. Skipping...
# Processing Record 48 of Set 4 | libreville
# Processing Record 49 of Set 4 | haputale
# Processing Record 50 of Set 4 | samusu
# City not found. Skipping...
# Processing Record 1 of Set 5 | mehamn
# Processing Record 2 of Set 5 | ngunguru
# Processing Record 3 of Set 5 | bathsheba
# Processing Record 4 of Set 5 | atambua
# Processing Record 5 of Set 5 | oga
# Processing Record 6 of Set 5 | kavieng
# Processing Record 7 of Set 5 | gat
# Processing Record 8 of Set 5 | paradwip
# City not found. Skipping...
# Processing Record 9 of Set 5 | erdenet
# Processing Record 10 of Set 5 | tiksi
# Processing Record 11 of Set 5 | severnyy-kospashskiy
# Processing Record 12 of Set 5 | nantucket
# Processing Record 13 of Set 5 | santana do acarau
# Processing Record 14 of Set 5 | isangel
# Processing Record 15 of Set 5 | guilin
# Processing Record 16 of Set 5 | saint-joseph
# Processing Record 17 of Set 5 | ponta delgada
# Processing Record 18 of Set 5 | saldanha
# Processing Record 19 of Set 5 | ribeira grande
# Processing Record 20 of Set 5 | san rafael
# Processing Record 21 of Set 5 | rovnoye
# Processing Record 22 of Set 5 | grindavik
# Processing Record 23 of Set 5 | dickinson
# Processing Record 24 of Set 5 | angra
# City not found. Skipping...
# Processing Record 25 of Set 5 | chara
# Processing Record 26 of Set 5 | mahebourg
# Processing Record 27 of Set 5 | avera
# Processing Record 28 of Set 5 | mukhtolovo
# Processing Record 29 of Set 5 | richards bay
# Processing Record 30 of Set 5 | wahiawa
# Processing Record 31 of Set 5 | lasa
# Processing Record 32 of Set 5 | yulara
# Processing Record 33 of Set 5 | rio gallegos
# Processing Record 34 of Set 5 | korla
# Processing Record 35 of Set 5 | kupang
# Processing Record 36 of Set 5 | ulladulla
# Processing Record 37 of Set 5 | college
# Processing Record 38 of Set 5 | padang
# Processing Record 39 of Set 5 | ludvika
# Processing Record 40 of Set 5 | airai
# Processing Record 41 of Set 5 | kitimat
# Processing Record 42 of Set 5 | leningradskiy
# Processing Record 43 of Set 5 | carnarvon
# Processing Record 44 of Set 5 | bonthe
# Processing Record 45 of Set 5 | pemangkat
# Processing Record 46 of Set 5 | khandyga
# Processing Record 47 of Set 5 | slave lake
# Processing Record 48 of Set 5 | winnemucca
# Processing Record 49 of Set 5 | solnechnyy
# Processing Record 50 of Set 5 | kodino
# Processing Record 1 of Set 6 | pashiya
# Processing Record 2 of Set 6 | caravelas
# Processing Record 3 of Set 6 | turukhansk
# Processing Record 4 of Set 6 | dawlatabad
# Processing Record 5 of Set 6 | dalby
# Processing Record 6 of Set 6 | cayenne
# Processing Record 7 of Set 6 | jega
# Processing Record 8 of Set 6 | kristiansund
# Processing Record 9 of Set 6 | kerteh
# City not found. Skipping...
# Processing Record 10 of Set 6 | ahvaz
# Processing Record 11 of Set 6 | sataua
# City not found. Skipping...
# Processing Record 12 of Set 6 | kichera
# Processing Record 13 of Set 6 | velingara
# Processing Record 14 of Set 6 | lewisporte
# Processing Record 15 of Set 6 | bambous virieux
# Processing Record 16 of Set 6 | chuy
# Processing Record 17 of Set 6 | san javier
# Processing Record 18 of Set 6 | camacha
# Processing Record 19 of Set 6 | maumere
# Processing Record 20 of Set 6 | anloga
# Processing Record 21 of Set 6 | makakilo city
# Processing Record 22 of Set 6 | nyurba
# Processing Record 23 of Set 6 | kahului
# Processing Record 24 of Set 6 | pindiga
# Processing Record 25 of Set 6 | rapid valley
# Processing Record 26 of Set 6 | linhai
# Processing Record 27 of Set 6 | baghdad
# Processing Record 28 of Set 6 | ibanda
# Processing Record 29 of Set 6 | kathu
# Processing Record 30 of Set 6 | acapulco
# Processing Record 31 of Set 6 | aberdeen
# Processing Record 32 of Set 6 | kapiri mposhi
# Processing Record 33 of Set 6 | xichang
# Processing Record 34 of Set 6 | sabha
# Processing Record 35 of Set 6 | gravdal
# Processing Record 36 of Set 6 | dunedin
# Processing Record 37 of Set 6 | lakatoro
# Processing Record 38 of Set 6 | brae
# Processing Record 39 of Set 6 | birao
# Processing Record 40 of Set 6 | manokwari
# Processing Record 41 of Set 6 | ballina
# Processing Record 42 of Set 6 | iqaluit
# Processing Record 43 of Set 6 | tongliao
# Processing Record 44 of Set 6 | artyk
# City not found. Skipping...
# Processing Record 45 of Set 6 | santa rosalia
# Processing Record 46 of Set 6 | vestmannaeyjar
# Processing Record 47 of Set 6 | dwarka
# Processing Record 48 of Set 6 | shurugwi
# Processing Record 49 of Set 6 | troitsko-pechorsk
# Processing Record 50 of Set 6 | pervomayskoye
# Processing Record 1 of Set 7 | meyungs
# City not found. Skipping...
# Processing Record 2 of Set 7 | hamilton
# Processing Record 3 of Set 7 | tsihombe
# City not found. Skipping...
# Processing Record 4 of Set 7 | kunda
# Processing Record 5 of Set 7 | bethanien
# Processing Record 6 of Set 7 | nikolskoye
# Processing Record 7 of Set 7 | constitucion
# Processing Record 8 of Set 7 | sibolga
# Processing Record 9 of Set 7 | portland
# Processing Record 10 of Set 7 | banda aceh
# Processing Record 11 of Set 7 | jizan
# Processing Record 12 of Set 7 | pevek
# Processing Record 13 of Set 7 | feira de santana
# Processing Record 14 of Set 7 | kamenskoye
# City not found. Skipping...
# Processing Record 15 of Set 7 | najran
# Processing Record 16 of Set 7 | okhotsk
# Processing Record 17 of Set 7 | nizhneyansk
# City not found. Skipping...
# Processing Record 18 of Set 7 | juneau
# Processing Record 19 of Set 7 | cabo san lucas
# Processing Record 20 of Set 7 | eresos
# Processing Record 21 of Set 7 | japura
# Processing Record 22 of Set 7 | bend
# Processing Record 23 of Set 7 | prince rupert
# Processing Record 24 of Set 7 | salinas
# Processing Record 25 of Set 7 | spokane
# Processing Record 26 of Set 7 | chengde
# Processing Record 27 of Set 7 | kashi
# Processing Record 28 of Set 7 | karema
# Processing Record 29 of Set 7 | batemans bay
# Processing Record 30 of Set 7 | storforshei
# Processing Record 31 of Set 7 | hede
# Processing Record 32 of Set 7 | hambantota
# Processing Record 33 of Set 7 | dzerzhinskoye
# Processing Record 34 of Set 7 | kaeo
# Processing Record 35 of Set 7 | cidreira
# Processing Record 36 of Set 7 | cassilandia
# Processing Record 37 of Set 7 | takapau
# Processing Record 38 of Set 7 | umzimvubu
# City not found. Skipping...
# Processing Record 39 of Set 7 | aflu
# City not found. Skipping...
# Processing Record 40 of Set 7 | piombino
# Processing Record 41 of Set 7 | ushtobe
# Processing Record 42 of Set 7 | ambilobe
# Processing Record 43 of Set 7 | uvira
# Processing Record 44 of Set 7 | sioux lookout
# Processing Record 45 of Set 7 | antalaha
# Processing Record 46 of Set 7 | manzanillo
# Processing Record 47 of Set 7 | coihaique
# Processing Record 48 of Set 7 | norman wells
# Processing Record 49 of Set 7 | gubden
# Processing Record 50 of Set 7 | rodeo
# Processing Record 1 of Set 8 | srandakan
# Processing Record 2 of Set 8 | kempten
# Processing Record 3 of Set 8 | narsaq
# Processing Record 4 of Set 8 | mount gambier
# Processing Record 5 of Set 8 | tukrah
# Processing Record 6 of Set 8 | ostrovnoy
# Processing Record 7 of Set 8 | tumannyy
# City not found. Skipping...
# Processing Record 8 of Set 8 | san cristobal
# Processing Record 9 of Set 8 | olafsvik
# Processing Record 10 of Set 8 | florianopolis
# Processing Record 11 of Set 8 | bengkulu
# Processing Record 12 of Set 8 | shingu
# Processing Record 13 of Set 8 | balkanabat
# Processing Record 14 of Set 8 | buala
# Processing Record 15 of Set 8 | chicama
# Processing Record 16 of Set 8 | todos santos
# Processing Record 17 of Set 8 | severnoye
# Processing Record 18 of Set 8 | mirandopolis
# Processing Record 19 of Set 8 | saint leonard
# Processing Record 20 of Set 8 | karaton
# Processing Record 21 of Set 8 | sahuaripa
# Processing Record 22 of Set 8 | sao joao da barra
# Processing Record 23 of Set 8 | moranbah
# Processing Record 24 of Set 8 | nouakchott
# Processing Record 25 of Set 8 | tuatapere
# Processing Record 26 of Set 8 | nago
# Processing Record 27 of Set 8 | sitka
# Processing Record 28 of Set 8 | fevralsk
# City not found. Skipping...
# Processing Record 29 of Set 8 | senneterre
# Processing Record 30 of Set 8 | poya
# Processing Record 31 of Set 8 | attawapiskat
# City not found. Skipping...
# Processing Record 32 of Set 8 | san juan
# Processing Record 33 of Set 8 | buraydah
# Processing Record 34 of Set 8 | cairns
# Processing Record 35 of Set 8 | negotin
# Processing Record 36 of Set 8 | omsukchan
# Processing Record 37 of Set 8 | kawana waters
# City not found. Skipping...
# Processing Record 38 of Set 8 | sebinkarahisar
# Processing Record 39 of Set 8 | qiongshan
# Processing Record 40 of Set 8 | hasaki
# Processing Record 41 of Set 8 | burgeo
# Processing Record 42 of Set 8 | muravlenko
# Processing Record 43 of Set 8 | khorramshahr
# Processing Record 44 of Set 8 | tabou
# Processing Record 45 of Set 8 | babanusah
# City not found. Skipping...
# Processing Record 46 of Set 8 | palmer
# Processing Record 47 of Set 8 | bonavista
# Processing Record 48 of Set 8 | sambava
# Processing Record 49 of Set 8 | batagay-alyta
# Processing Record 50 of Set 8 | aswan
# Processing Record 1 of Set 9 | vao
# Processing Record 2 of Set 9 | vila franca do campo
# Processing Record 3 of Set 9 | mahadday weyne
# City not found. Skipping...
# Processing Record 4 of Set 9 | saint-paul
# Processing Record 5 of Set 9 | evensk
# Processing Record 6 of Set 9 | moroni
# Processing Record 7 of Set 9 | gornopravdinsk
# Processing Record 8 of Set 9 | mpika
# Processing Record 9 of Set 9 | hualmay
# Processing Record 10 of Set 9 | rivadavia
# Processing Record 11 of Set 9 | matamoros
# Processing Record 12 of Set 9 | acari
# Processing Record 13 of Set 9 | tura
# Processing Record 14 of Set 9 | ambon
# Processing Record 15 of Set 9 | vila do maio
# Processing Record 16 of Set 9 | panzhihua
# Processing Record 17 of Set 9 | batsfjord
# Processing Record 18 of Set 9 | ulaanbaatar
# Processing Record 19 of Set 9 | martapura
# Processing Record 20 of Set 9 | vung tau
# Processing Record 21 of Set 9 | zapolyarnyy
# Processing Record 22 of Set 9 | polovinnoye
# Processing Record 23 of Set 9 | sao filipe
# Processing Record 24 of Set 9 | bilma
# Processing Record 25 of Set 9 | lorengau
# Processing Record 26 of Set 9 | hofn
# Processing Record 27 of Set 9 | utamysh
# Processing Record 28 of Set 9 | warri
# Processing Record 29 of Set 9 | luanda
# Processing Record 30 of Set 9 | kismayo
# Processing Record 31 of Set 9 | van buren
# Processing Record 32 of Set 9 | barbar
# City not found. Skipping...
# Processing Record 33 of Set 9 | lagoa
# Processing Record 34 of Set 9 | kattivakkam
# Processing Record 35 of Set 9 | lashio
# Processing Record 36 of Set 9 | nipawin
# Processing Record 37 of Set 9 | nabire
# Processing Record 38 of Set 9 | semme
# Processing Record 39 of Set 9 | yanan
# City not found. Skipping...
# Processing Record 40 of Set 9 | sorland
# Processing Record 41 of Set 9 | ialibu
# Processing Record 42 of Set 9 | boa vista
# Processing Record 43 of Set 9 | roma
# Processing Record 44 of Set 9 | gaur
# Processing Record 45 of Set 9 | katsuura
# Processing Record 46 of Set 9 | adjumani
# Processing Record 47 of Set 9 | hay river
# Processing Record 48 of Set 9 | mandera
# Processing Record 49 of Set 9 | puerto madryn
# Processing Record 50 of Set 9 | fershampenuaz
# Processing Record 1 of Set 10 | te anau
# Processing Record 2 of Set 10 | peace river
# Processing Record 3 of Set 10 | lucapa
# Processing Record 4 of Set 10 | gurgan
# City not found. Skipping...
# Processing Record 5 of Set 10 | bababe
# City not found. Skipping...
# Processing Record 6 of Set 10 | torbay
# Processing Record 7 of Set 10 | ayan
# Processing Record 8 of Set 10 | manaure
# Processing Record 9 of Set 10 | pontal do parana
# Processing Record 10 of Set 10 | cabedelo
# Processing Record 11 of Set 10 | nelson bay
# Processing Record 12 of Set 10 | zhicheng
# Processing Record 13 of Set 10 | northam
# Processing Record 14 of Set 10 | voh
# Processing Record 15 of Set 10 | hinton
# Processing Record 16 of Set 10 | lujan
# Processing Record 17 of Set 10 | dongsheng
# Processing Record 18 of Set 10 | yar-sale
# Processing Record 19 of Set 10 | puro
# Processing Record 20 of Set 10 | tanout
# Processing Record 21 of Set 10 | zhigansk
# Processing Record 22 of Set 10 | bonawon
# Processing Record 23 of Set 10 | nemuro
# Processing Record 24 of Set 10 | yambio
# Processing Record 25 of Set 10 | havre-saint-pierre
# Processing Record 26 of Set 10 | karaul
# City not found. Skipping...
# Processing Record 27 of Set 10 | ashqelon
# Processing Record 28 of Set 10 | shache
# Processing Record 29 of Set 10 | ibia
# Processing Record 30 of Set 10 | kaspiysk
# Processing Record 31 of Set 10 | iracoubo
# Processing Record 32 of Set 10 | ilhabela
# Processing Record 33 of Set 10 | aksha
# Processing Record 34 of Set 10 | mapiripan
# Processing Record 35 of Set 10 | marica
# Processing Record 36 of Set 10 | antigonish
# Processing Record 37 of Set 10 | ararangua
# Processing Record 38 of Set 10 | osmena
# Processing Record 39 of Set 10 | salalah
# Processing Record 40 of Set 10 | maldonado
# Processing Record 41 of Set 10 | san carlos del zulia
# Processing Record 42 of Set 10 | irbit
# Processing Record 43 of Set 10 | tiffin
# Processing Record 44 of Set 10 | bhainsa
# Processing Record 45 of Set 10 | romny
# Processing Record 46 of Set 10 | chengmai
# City not found. Skipping...
# Processing Record 47 of Set 10 | izazi
# Processing Record 48 of Set 10 | chernyshevskiy
# Processing Record 49 of Set 10 | chilca
# Processing Record 50 of Set 10 | adrar
# Processing Record 1 of Set 11 | amderma
# City not found. Skipping...
# Processing Record 2 of Set 11 | lugovskiy
# City not found. Skipping...
# Processing Record 3 of Set 11 | old road
# City not found. Skipping...
# Processing Record 4 of Set 11 | severomuysk
# Processing Record 5 of Set 11 | nara
# Processing Record 6 of Set 11 | mahon
# Processing Record 7 of Set 11 | altay
# Processing Record 8 of Set 11 | aripuana
# Processing Record 9 of Set 11 | krasnoselkup
# Processing Record 10 of Set 11 | brokopondo
# Processing Record 11 of Set 11 | santiago
# Processing Record 12 of Set 11 | cerritos
# Processing Record 13 of Set 11 | katobu
# Processing Record 14 of Set 11 | ukhta
# Processing Record 15 of Set 11 | sapa
# Processing Record 16 of Set 11 | kalabo
# Processing Record 17 of Set 11 | oistins
# Processing Record 18 of Set 11 | tunduru
# City not found. Skipping...
# Processing Record 19 of Set 11 | manica
# Processing Record 20 of Set 11 | teluknaga
# Processing Record 21 of Set 11 | ondorhaan
# City not found. Skipping...
# Processing Record 22 of Set 11 | bud
# Processing Record 23 of Set 11 | puerto ayacucho
# Processing Record 24 of Set 11 | sept-iles
# Processing Record 25 of Set 11 | hobyo
# Processing Record 26 of Set 11 | puerto quijarro
# Processing Record 27 of Set 11 | biankouma
# Processing Record 28 of Set 11 | pozo colorado
# Processing Record 29 of Set 11 | keetmanshoop
# Processing Record 30 of Set 11 | mountain home
# Processing Record 31 of Set 11 | rho
# Processing Record 32 of Set 11 | qarayeri
# Processing Record 33 of Set 11 | play cu
# City not found. Skipping...
# Processing Record 34 of Set 11 | sinkat
# City not found. Skipping...
# Processing Record 35 of Set 11 | innisfail
# Processing Record 36 of Set 11 | tautira
# Processing Record 37 of Set 11 | kenai
# Processing Record 38 of Set 11 | binghamton
# Processing Record 39 of Set 11 | ati
# Processing Record 40 of Set 11 | bac lieu
# Processing Record 41 of Set 11 | sorkjosen
# Processing Record 42 of Set 11 | laborie
# Processing Record 43 of Set 11 | concepcion del oro
# Processing Record 44 of Set 11 | oranjemund
# Processing Record 45 of Set 11 | tovste
# Processing Record 46 of Set 11 | poum
# Processing Record 47 of Set 11 | sangar
# Processing Record 48 of Set 11 | ville-marie
# Processing Record 49 of Set 11 | kikwit
# Processing Record 50 of Set 11 | seydi
# Processing Record 1 of Set 12 | faya
# Processing Record 2 of Set 12 | saint-georges
# Processing Record 3 of Set 12 | quatre cocos
# Processing Record 4 of Set 12 | lolua
# City not found. Skipping...
# Processing Record 5 of Set 12 | derzhavinsk
# Processing Record 6 of Set 12 | port blair
# Processing Record 7 of Set 12 | camocim
# Processing Record 8 of Set 12 | tougan
# Processing Record 9 of Set 12 | ust-kut
# Processing Record 10 of Set 12 | ruatoria
# City not found. Skipping...
# Processing Record 11 of Set 12 | kaberamaido
# Processing Record 12 of Set 12 | lagos
# Processing Record 13 of Set 12 | calvinia
# Processing Record 14 of Set 12 | trairi
# Processing Record 15 of Set 12 | fukue
# Processing Record 16 of Set 12 | san severo
# Processing Record 17 of Set 12 | tapalpa
# Processing Record 18 of Set 12 | urumqi
# Processing Record 19 of Set 12 | panama city
# Processing Record 20 of Set 12 | brownsville
# Processing Record 21 of Set 12 | turtkul
# City not found. Skipping...
# Processing Record 22 of Set 12 | jalu
# Processing Record 23 of Set 12 | gebre guracha
# Processing Record 24 of Set 12 | jiangyou
# Processing Record 25 of Set 12 | old orchard beach
# Processing Record 26 of Set 12 | nizhnevartovsk
# Processing Record 27 of Set 12 | vimperk
# Processing Record 28 of Set 12 | bambanglipuro
# Processing Record 29 of Set 12 | broken hill
# Processing Record 30 of Set 12 | havoysund
# Processing Record 31 of Set 12 | verkhnyaya inta
# Processing Record 32 of Set 12 | imbituba
# Processing Record 33 of Set 12 | agfalva
# Processing Record 34 of Set 12 | san luis
# Processing Record 35 of Set 12 | inuvik
# Processing Record 36 of Set 12 | laguna
# Processing Record 37 of Set 12 | hami
# Processing Record 38 of Set 12 | iquique
# Processing Record 39 of Set 12 | tornio
# Processing Record 40 of Set 12 | paramonga
# Processing Record 41 of Set 12 | karpathos
# Processing Record 42 of Set 12 | chapais
# Processing Record 43 of Set 12 | port-cartier
# Processing Record 44 of Set 12 | higuey
# City not found. Skipping...
# Processing Record 45 of Set 12 | vanavara
# Processing Record 46 of Set 12 | huarmey
# Processing Record 47 of Set 12 | marcona
# City not found. Skipping...
# Processing Record 48 of Set 12 | yining
# Processing Record 49 of Set 12 | aksarka
# Processing Record 50 of Set 12 | qitaihe
# Processing Record 1 of Set 13 | walvis bay
# Processing Record 2 of Set 13 | anadyr
# Processing Record 3 of Set 13 | along
# Processing Record 4 of Set 13 | dzhebariki-khaya
# Processing Record 5 of Set 13 | pangnirtung
# Processing Record 6 of Set 13 | mosquera
# Processing Record 7 of Set 13 | manikling
# Processing Record 8 of Set 13 | kedrovyy
# Processing Record 9 of Set 13 | akyab
# Processing Record 10 of Set 13 | adet
# Processing Record 11 of Set 13 | pangai
# Processing Record 12 of Set 13 | charagua
# Processing Record 13 of Set 13 | ngukurr
# City not found. Skipping...
# Processing Record 14 of Set 13 | halalo
# City not found. Skipping...
# Processing Record 15 of Set 13 | miranorte
# City not found. Skipping...
# Processing Record 16 of Set 13 | gazli
# Processing Record 17 of Set 13 | barcelos
# Processing Record 18 of Set 13 | soe
# Processing Record 19 of Set 13 | zhangye
# Processing Record 20 of Set 13 | abong mbang
# Processing Record 21 of Set 13 | broome
# Processing Record 22 of Set 13 | buchanan
# Processing Record 23 of Set 13 | satitoa
# City not found. Skipping...
# Processing Record 24 of Set 13 | santa marta
# Processing Record 25 of Set 13 | nguiu
# City not found. Skipping...
# Processing Record 26 of Set 13 | ust-shonosha
# Processing Record 27 of Set 13 | alofi
# Processing Record 28 of Set 13 | maltahohe
# Processing Record 29 of Set 13 | namatanai
# Processing Record 30 of Set 13 | malanje
# Processing Record 31 of Set 13 | sikasso
# Processing Record 32 of Set 13 | honiara
# Processing Record 33 of Set 13 | zaraza
# Processing Record 34 of Set 13 | abhar
# Processing Record 35 of Set 13 | kyra
# Processing Record 36 of Set 13 | dakar
# Processing Record 37 of Set 13 | yerbogachen
# Processing Record 38 of Set 13 | linqing
# Processing Record 39 of Set 13 | bongaree
# Processing Record 40 of Set 13 | tecoanapa
# Processing Record 41 of Set 13 | ware
# Processing Record 42 of Set 13 | pilar
# Processing Record 43 of Set 13 | bourail
# Processing Record 44 of Set 13 | hervey bay
# Processing Record 45 of Set 13 | maputo
# Processing Record 46 of Set 13 | jabiru
# City not found. Skipping...
# Processing Record 47 of Set 13 | nioro
# Processing Record 48 of Set 13 | almaznyy
# Processing Record 49 of Set 13 | krasnooktyabrskiy
# Processing Record 50 of Set 13 | ust-omchug
# Processing Record 1 of Set 14 | kilindoni
# Processing Record 2 of Set 14 | lata
# Processing Record 3 of Set 14 | pinega
# Processing Record 4 of Set 14 | sola
# Processing Record 5 of Set 14 | iquitos
# Processing Record 6 of Set 14 | podporozhye
# Processing Record 7 of Set 14 | arlit
# Processing Record 8 of Set 14 | nouadhibou
# Processing Record 9 of Set 14 | mayor pablo lagerenza
# Processing Record 10 of Set 14 | sanguem
# Processing Record 11 of Set 14 | poso
# Processing Record 12 of Set 14 | pisco
# Processing Record 13 of Set 14 | naron
# Processing Record 14 of Set 14 | constantine
# Processing Record 15 of Set 14 | florence
# Processing Record 16 of Set 14 | shimoda
# Processing Record 17 of Set 14 | vostok
# Processing Record 18 of Set 14 | jurm
# Processing Record 19 of Set 14 | leshukonskoye
# Processing Record 20 of Set 14 | yarega
# Processing Record 21 of Set 14 | tabiauea
# City not found. Skipping...
# Processing Record 22 of Set 14 | manzil salim
# Processing Record 23 of Set 14 | vanimo
# Processing Record 24 of Set 14 | vadso
# Processing Record 25 of Set 14 | chute-aux-outardes
# Processing Record 26 of Set 14 | darnah
# Processing Record 27 of Set 14 | waipawa
# Processing Record 28 of Set 14 | port angeles
# Processing Record 29 of Set 14 | araguaina
# Processing Record 30 of Set 14 | caninde
# Processing Record 31 of Set 14 | bardiyah
# Processing Record 32 of Set 14 | iranshahr
# Processing Record 33 of Set 14 | la ronge
# Processing Record 34 of Set 14 | labuhan
# Processing Record 35 of Set 14 | sana
# Processing Record 36 of Set 14 | hearst
# Processing Record 37 of Set 14 | sibu
# Processing Record 38 of Set 14 | zyryanka
# Processing Record 39 of Set 14 | balkhash
# Processing Record 40 of Set 14 | lat yao
# Processing Record 41 of Set 14 | buta
# Processing Record 42 of Set 14 | marsa matruh
# Processing Record 43 of Set 14 | abha
# Processing Record 44 of Set 14 | petlawad
# Processing Record 45 of Set 14 | husavik
# Processing Record 46 of Set 14 | haicheng
# Processing Record 47 of Set 14 | andenes
# Processing Record 48 of Set 14 | cherskiy

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)

# %%
new_column_order = ["City", "Country", "Date", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]
city_data_df = city_data_df[new_column_order]
city_data_df.head(10)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-18-d77283e97abd> in <module>
#       1 new_column_order = ["City", "Country", "Date", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]
# ----> 2 city_data_df = city_data_df[new_column_order]
#       3 city_data_df.head(10)
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2906             if is_iterator(key):
#    2907                 key = list(key)
# -> 2908             indexer = self.loc._get_listlike_indexer(key, axis=1, raise_missing=True)[1]
#    2909
#    2910         # take() does not accept boolean indexers
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\core\indexing.py in _get_listlike_indexer(self, key, axis, raise_missing)
#    1252             keyarr, indexer, new_indexer = ax._reindex_non_unique(keyarr)
#    1253
# -> 1254         self._validate_read_indexer(keyarr, indexer, axis, raise_missing=raise_missing)
#    1255         return keyarr, indexer
#    1256
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\core\indexing.py in _validate_read_indexer(self, key, indexer, axis, raise_missing)
#    1296             if missing == len(indexer):
#    1297                 axis_name = self.obj._get_axis_name(axis)
# -> 1298                 raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    1299
#    1300             # We (temporarily) allow for some missing keys with .loc, except in
#
# KeyError: "None of [Index(['City', 'Country', 'Date', 'Lat', 'Lng', 'Max Temp', 'Humidity',\n       'Cloudiness', 'Wind Speed', 'Current Description'],\n      dtype='object')] are in the [columns]"

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/Weather_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
